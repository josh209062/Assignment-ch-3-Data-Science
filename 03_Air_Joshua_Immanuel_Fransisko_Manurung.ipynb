# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
data = pd.read_csv('https://raw.githubusercontent.com/Rietaros/kampus_merdeka/main/HRDataset_v14.csv')
data.head()
# Out:
#               Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0       Adinolfi, Wilson  K  10026          0                0         1
# 1  Ait Sidi, Karthikeyan     10084          1                1         1
# 2         Akinkuolie, Sarah  10196          1                1         0
# 3              Alagbe,Trina  10088          1                1         0
# 4          Anderson, Carol   10069          0                2         0
#
#    EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  Salary  Termd  \
# 0            1       5            4                       0   62506      0
# 1            5       3            3                       0  104437      1
# 2            5       5            3                       0   64955      1
# 3            1       5            3                       0   64991      0
# 4            5       5            3                       0   50825      1
#
# ...

# %% [markdown]
# # Pandas Question

# %% [markdown]
# 1. What is the minimum, median, max, and average salary for employee by Married Description and Gender.
# Hints: use agg function<br>
# Expected Output as below<br>
# (5 Points)

# %%
# 1. What is the minimum, median, max, and average salary for employee by Married Description and Gender
# Hints: use agg function
# Expected Output as below
# (5 Points)
data.groupby(by=['MaritalDesc', 'Sex']).agg(
    min_salary=('Salary', 'min'),
    median_salary=('Salary', 'median'),
    max_salary=('Salary', 'max'),
    average_salary=('Salary', 'mean')
)
# Out:
#                  min_salary  median_salary  max_salary  average_salary
# MaritalDesc Sex
# Divorced    F         45069        59393.0       68182    57345.500000
#             M         45115        63738.5      148999    72520.857143
# Married     F         45433        62662.0      250000    69638.986111
#             M         46120        63370.5      157000    70089.038462
# Separated   F         52984        60627.0       66149    60658.888889
#             M         64397        70468.0       74417    69760.666667
# Single      F         45395        62068.0      220450    68988.266667
#             M         46428        63055.5      178000    71340.048387
# Widowed     F         45046        63303.5      107226    69719.750000
#             M         52788        61359.0       67176    60670.500000

# %% [markdown]
# 2. What is top-5 reason of termination?<br>
# Expected Output as below<br>
# (5 Points)

# %%
#code here
data.groupby(by='TermReason').agg(
    total_termination=('TermReason', 'count')
).sort_values(by='total_termination', ascending=False).head()
# Out:
#                    total_termination
# TermReason
# N/A-StillEmployed                207
# Another position                  20
# unhappy                           14
# more money                        11
# career change                      9

# %% [markdown]
# 3. What is the highest number of employee by Recruitment Source that 'Exceeds' the Performance Score?
# Hints: Use filter for Performance Score first. Don't forget to sort_values.<br>
# Expected Output as below<br>
# (5 Points)

# %%
#code here
perform_data = data[data['PerformanceScore'] == 'Exceeds']

perform_data.groupby('RecruitmentSource').agg(
    total_recruit=('PerformanceScore', 'count')
).sort_values(by='total_recruit', ascending=False)
# Out:
#                     total_recruit
# RecruitmentSource
# Indeed                         12
# LinkedIn                        9
# Diversity Job Fair              6
# Employee Referral               5
# CareerBuilder                   2
# Google Search                   2
# Website                         1

# %% [markdown]
# 4. How many managers in each department?
# Hints: use nunique() as aggregation function.<br>
# Expected Output as below.<br>
# (5 Points)

# %%
#code here
data.groupby(by='Department').agg({
    'ManagerName': 'nunique'
}).sort_values(by='Department', ascending=True)
# Out:
#                       ManagerName
# Department
# Admin Offices                   3
# Executive Office                1
# IT/IS                           6
# Production                     10
# Sales                           4
# Software Engineering            3

# %% [markdown]
# 5. What is Termination Ratio by Gender?.
# Hints: use value_counts(normalize=True).<br>
# Expected Output as below.<br>
# (5 Points)

# %%
#code here
data.groupby(by='Sex').Termd.value_counts(normalize=True)
# Out:
# Sex  Termd
# F    0        0.659091
#      1        0.340909
# M    0        0.674074
#      1        0.325926
# Name: Termd, dtype: float64

# %% [markdown]
# # Create an EDA and Data Visualization Question

# %%
#Sample Visualization, the example is not counted for the final score :p
#Create 5 visualization for better understanding on data
from matplotlib import pyplot as plt
import seaborn as sns
import numpy as np

#Ratio termination by Gender

#Step1, get the data

term = data.groupby(by=['Sex'])\
                        .agg(total_termination=('Termd','sum')).reset_index()\

#Step2, Plot it
f, ax = plt.subplots(1, 1, figsize=(12, 8))
ax = sns.barplot(x='Sex', y='total_termination', hue='Sex', data=term, palette='cool')

# %% [markdown]
# 6. Buatlah Scatter plot antara kolom "Salary" dengan "EngagementSurvey", beri warna berbeda sesuai dengan status di "Termd"<br>
# (5 points)<br>
# *bentuk output di bawah hanya contoh*

# %%
#code here
plt.figure(figsize=(8, 6))
sns.scatterplot(
    x='Salary',
    y='EngagementSurvey',
    hue='Termd',
    data=data
)
plt.title('Salary vs EngagementSurvey')
plt.show()

# %% [markdown]
# 7. Buatlah visualisasi barchart untuk menghitung jumlah "termination of an employee's" berdasarkan department.<br>
# (5 points)<br>
# *bentuk output di bawah hanya contoh*

# %%
termination = data.groupby(by='Department').agg({
    'Termd': 'sum'
}).reset_index().sort_values(by='Termd', ascending=False)

plt.figure(figsize=(8, 6))
sns.barplot(x=termination['Termd'], y=termination['Department'], label=termination['Department'])
plt.legend()
plt.title('Termination of an Employee\'s')
plt.show()

# %% [markdown]
# 8. Buatlah visualisasi Pie Chart untuk melihat persentasi jumlah karyawan yang "terminated" berdasarkan kolom "Position".<br>
# (5 points)<br>
# *bentuk output di bawah hanya contoh*

# %%
terminated = data[data['Termd'] == 1]['Position'].value_counts().sort_values(ascending=False)

plt.figure(figsize=(10, 6))
plt.pie(
    x=terminated,
    labels=terminated.index,
    autopct='%1.1f%%'
)
plt.title('Percentage of Terminated Employee\'s by Position')
plt.show()

# %% [markdown]
# 9. Buat Boxplot yang menggambarkan Salary berdasarkan Marital Desc, bedakan berdasarkan Termd
# (5 points)

# %%
#code here
plt.figure(figsize=(10, 6))

sns.boxplot(
    x=data['Salary'],
    y=data['MaritalDesc'],
    hue=data['Termd'],
    data=data
)
plt.title('Salary Based on Marital Desc by Termd')
plt.show()

# %% [markdown]
# 10. Tampilkan pairplot antara kolom 'Salary', 'EngagementSurvey', 'EmpSatisfaction','Absences'
# beri kategori warna berdasarkan 'Termd'<br>
# (5points)

# %%
#codde here
print('Pairplot')
sns.pairplot(data=data[['Salary', 'EngagementSurvey', 'EmpSatisfaction','Absences', 'Termd']], hue='Termd', height=3, diag_kind="hist")
plt.show()
# Out:
# Pairplot

# %% [markdown]
# # Create Machine Learning Model to Predict Termd and Question

# %%
#11. Buat fitur baru (kolom baru) berupa "Age" dalam satuan tahun. Untuk mendapatkannya, ambil data pada kolom DOB dikurangi dengan 2022
#(5 points)
data['DOB_date'] = pd.to_datetime(data['DOB'])
data['Year'] = data['DOB_date'].dt.year
data['Age'] = 2022 - data['Year']

data[['DOB', 'DOB_date','Age']]
# Out:
#           DOB   DOB_date  Age
# 0    07/10/83 1983-07-10   39
# 1    05/05/75 1975-05-05   47
# 2    09/19/88 1988-09-19   34
# 3    09/27/88 1988-09-27   34
# 4    09/08/89 1989-09-08   33
# ..        ...        ...  ...
# 306  05/11/85 1985-05-11   37
# 307  05/04/82 1982-05-04   40
# 308  08/30/79 1979-08-30   43
# 309  02/24/79 1979-02-24   43
# 310  08/17/78 1978-08-17   44
#
# [311 rows x 3 columns]

# %%
#12. Lakukan MinMaxScaler dari fitur "Salary"
# (5 points)
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
data['Salary_minmax'] = scaler.fit_transform(data[['Salary']])

data[['Salary','Salary_minmax']]
# Out:
#      Salary  Salary_minmax
# 0     62506       0.085190
# 1    104437       0.289777
# 2     64955       0.097139
# 3     64991       0.097315
# 4     50825       0.028197
# ..      ...            ...
# 306   65893       0.101716
# 307   48513       0.016916
# 308  220450       0.855821
# 309   89292       0.215883
# 310   45046       0.000000
#
# [311 rows x 2 columns]

# %%
#13. Ubahlah semua tipe data object menjadi category
# 5 point
data.dtypes
# Out:
# Employee_Name                         object
# EmpID                                  int64
# MarriedID                              int64
# MaritalStatusID                        int64
# GenderID                               int64
# EmpStatusID                            int64
# DeptID                                 int64
# PerfScoreID                            int64
# FromDiversityJobFairID                 int64
# Salary                                 int64
# Termd                                  int64
# PositionID                             int64
# Position                              object
# State                                 object
# Zip                                    int64
# DOB                                   object
# Sex                                   object
# MaritalDesc                           object
# CitizenDesc                           object
# HispanicLatino                        object
# RaceDesc                              object
# ...

# %%
dtype_object = data.select_dtypes(include=['object']).columns
for col in dtype_object:
  data[col] = data[col].astype('category')
#Setelah diubah category
data.dtypes
# Out:
# Employee_Name                       category
# EmpID                                  int64
# MarriedID                              int64
# MaritalStatusID                        int64
# GenderID                               int64
# EmpStatusID                            int64
# DeptID                                 int64
# PerfScoreID                            int64
# FromDiversityJobFairID                 int64
# Salary                                 int64
# Termd                                  int64
# PositionID                             int64
# Position                            category
# State                               category
# Zip                                    int64
# DOB                                 category
# Sex                                 category
# MaritalDesc                         category
# CitizenDesc                         category
# HispanicLatino                      category
# RaceDesc                            category
# ...

# %%
from sklearn.preprocessing import LabelEncoder
#14. Ubahlah "RecruitmentSource" dengan menggunakana Label Encoder
# 5 point
label_encoder = LabelEncoder()
data['RecruitmentSource'] = label_encoder.fit_transform(data['RecruitmentSource'])

#15. Ubahlah "PerformanceScore" dengan menggunakana Label Encoder
# 5 point
data['PerformanceScore'] = label_encoder.fit_transform(data['PerformanceScore'])

# %%
#16. Pisahkan dependent variable dan independent variable
# 5 point

#Dependent Varible (target)
y = data['Termd']

#Independent Variable (feature)
x = data[['MarriedID',	'MaritalStatusID',	'GenderID',	'DeptID',	'PerfScoreID',
          'PositionID',	'Age',	'RecruitmentSource',	'PerformanceScore',	'Salary_minmax',
          'Absences',	'SpecialProjectsCount',	'EmpSatisfaction',	'EngagementSurvey']]
x.head()
# Out:
#    MarriedID  MaritalStatusID  GenderID  DeptID  PerfScoreID  PositionID  Age  \
# 0          0                0         1       5            4          19   39
# 1          1                1         1       3            3          27   47
# 2          1                1         0       5            3          20   34
# 3          1                1         0       5            3          19   34
# 4          0                2         0       5            3          19   33
#
#    RecruitmentSource  PerformanceScore  Salary_minmax  Absences  \
# 0                  5                 0       0.085190         1
# 1                  4                 1       0.289777        17
# 2                  5                 1       0.097139         3
# 3                  4                 1       0.097315        15
# 4                  3                 1       0.028197         2
#
#    SpecialProjectsCount  EmpSatisfaction  EngagementSurvey
# ...

# %%
#17. Bagi data menjadi Train-Test sebesar 80:20
# (5 points)
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_recall_curve, roc_curve, precision_score, recall_score

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=25)
print('Train set shape (x_train, y_train): ', x_train.shape, y_train.shape)
print('Test set shape (x_test, y_test): ', x_test.shape, y_test.shape)
# Out:
# Train set shape (x_train, y_train):  (248, 14) (248,)
# Test set shape (x_test, y_test):  (63, 14) (63,)

# %%
#18. Lakukan pemodelan machine learning (metode klasifikasi bebas) untuk bisa memprediksi status "Termd". Lakukan evaluasi hasil dengan menampilkan
# score klasifikasi, precision dan recall.
# Gunakan model yang menurut kalian terbaik
# (5 points)
from sklearn.linear_model import LogisticRegression
model = LogisticRegression(tol=0.00001, C=1, max_iter=1000, penalty = 'none')
train_model = model.fit(x_train, y_train)

y_pred = train_model.predict(x_test)
predictions = [round(value) for value in y_pred]

accuracy = accuracy_score(y_test, predictions)
precision = precision_score(y_test, predictions)
recall = recall_score(y_test, predictions)
print("Accuracy  %.2f%%" % (accuracy * 100.0))
print("Precision : %.2f%%" % (precision* 100.0))
print("Recall : %.2f%%" % (recall * 100.0))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# Accuracy  74.60%
# Precision : 63.64%
# Recall : 36.84%

# %% [markdown]
# # Insight (Answering the Question)
#
# 19.	Is there any relationship between who a person works for (their manager) and their performance score? (5 points)<br>
# 20.	What are our best recruiting sources if we want to ensure a low ratio of termination? (5 points)<br>

# %% [markdown]
# ## 19. Is there any relationship between who a person works for (their manager) and their performance score? (5 points)

# %%
datas = data.groupby(by='ManagerName').agg({
    'PerformanceScore': 'count'
}).sort_values(by='ManagerName', ascending=True).reset_index()
plt.figure(figsize=(12, 8))
sns.barplot(x=datas['PerformanceScore'], y=datas['ManagerName'])
plt.title('Manager VS Performance Score')
plt.show()

# %%
datas.sort_values(by='PerformanceScore', ascending=False).head(5)
# Out:
#        ManagerName  PerformanceScore
# 17  Michael Albert                22
# 15  Kissy Sullivan                22
# 4   Brannon Miller                22
# 13   Kelley Spirea                22
# 8     Elijiah Gray                22

# %% [markdown]
# Dari Hasil Output data diatas kita dapat melihat 5 manager dengan karyawan terbanyak. Selanjutnya kita perlu melihat apakah setiap karyawan dari manager tersebut memiliki performance score yang baik atau tidak.

# %%
Exceeds = data[data['PerformanceScore'] == 0]
FullyMeets = data[data['PerformanceScore'] == 1]
NeedImprovements = data[data['PerformanceScore'] == 2]
PIP = data[data['PerformanceScore'] == 3]

# %%
exceeds_df = Exceeds.groupby(by='ManagerName').agg(
    total_exceeds=('ManagerName','count')
).sort_values(by='total_exceeds', ascending=False)
plt.figure(figsize=(6, 5))
sns.barplot(x=exceeds_df['total_exceeds'], y=exceeds_df.index)
plt.title('Manager VS Performance Score (Exceeds)')
plt.show()

# %%
exceeds_df.head(5)
# Out:
#                 total_exceeds
# ManagerName
# Brannon Miller              7
# Janet King                  4
# Amy Dunn                    3
# Kelley Spirea               3
# Simon Roup                  2

# %% [markdown]
# Dari hasil output ini kita dapat melihat bahwasanya top 5 manager dengan karyawan terbanyak dengan performance score exceed, atau yang terbilang sangat melebihi ekspetasi.

# %%
fully_df = FullyMeets.groupby(by='ManagerName').agg(
    total_fully=('ManagerName','count')
).sort_values(by='total_fully', ascending=False)
plt.figure(figsize=(6, 5))
sns.barplot(x=fully_df['total_fully'], y=fully_df.index)
plt.title('Manager VS Performance Score (Fully Meets)')
plt.show()

# %%
fully_df.head(5)
# Out:
#                 total_fully
# ManagerName
# David Stanley            19
# Kissy Sullivan           18
# Ketsia Liebig            18
# Elijiah Gray             18
# Kelley Spirea            18

# %% [markdown]
# Disini kita dapat melihat top 5 manager dengan karyawan terbanyak yang memiliki performance score Fully Meets, yang artinya karyawan yang memenuhi ekspetasi kerja.

# %%
need_df = NeedImprovements.groupby(by='ManagerName').agg(
    total_need=('ManagerName','count')
).sort_values(by='total_need', ascending=False)
plt.figure(figsize=(6, 5))
sns.barplot(x=need_df['total_need'], y=need_df.index)
plt.title('Manager VS Performance Score (Need Improvements)')
plt.show()

# %%
need_df.head(5)
# Out:
#                 total_need
# ManagerName
# Michael Albert           3
# Janet King               2
# Elijiah Gray             2
# Webster Butler           2
# Brannon Miller           1

# %% [markdown]
# Disini kita dapat melihat top 5 manager dengan karyawan terbanyak yang memiliki performance score Need Improvement, yang artinya karyawan yang dibawah ekspetasi kerja.

# %%
pip_df = PIP.groupby(by='ManagerName').agg(
    total_pip=('ManagerName','count')
).sort_values(by='total_pip', ascending=False)
plt.figure(figsize=(6, 5))
sns.barplot(x=pip_df['total_pip'], y=pip_df.index)
plt.title('Manager VS Performance Score (PIP)')
plt.show()

# %%
pip_df.head(5)
# Out:
#                 total_pip
# ManagerName
# Brannon Miller          4
# John Smith              2
# Lynn Daneault           2
# Amy Dunn                2
# Peter Monroe            1

# %% [markdown]
# Disini kita dapat melihat top 5 manager dengan karyawan terbanyak yang memiliki performance score PIP, yang artinya karyawan memerlukan perhatian khusus agar dapat bekerja lebih baik lagi.

# %% [markdown]
# Dari Pemaparan diatas dapat disimpulkan bahwasanya ada relasi antara karyawan dengan siapa manajernya dalam hal Skor Performa pekerjaannya. dan jugav performa dari seorang karyawan dipengaruhi oleh manajernya. jika managernya memperlakukan karyawan nya dengan baik, serta membimbing disetiap pekerjaannya maka karyawan tersebut akan memiliki performa yang baik. dan begitu pula sebaliknya sebaliknya.

# %% [markdown]
# ## 20. What are our best recruiting sources if we want to ensure a low ratio of termination? (5 points)

# %%
dataset = pd.read_csv('https://raw.githubusercontent.com/Rietaros/kampus_merdeka/main/HRDataset_v14.csv')
#code here
data = dataset.groupby(by='RecruitmentSource').agg({
   'Termd': 'count'
}).sort_values(by='Termd', ascending=False)
data
# Out:
#                          Termd
# RecruitmentSource
# Indeed                      87
# LinkedIn                    76
# Google Search               49
# Employee Referral           31
# Diversity Job Fair          29
# CareerBuilder               23
# Website                     13
# Other                        2
# On-line Web application      1

# %% [markdown]
# Berdasarkan output diatas dapat kita lihat total karyawan yang diterima bekerja melalui jalur rekruitmenya dimana paling tertinggi adalah jalur Indeed dengan karyawan sebanyak 87 dan yang terendah melalui jalur online web application.

# %%
dataset_0 = dataset[dataset['Termd'] == 0]
datas_0 = dataset_0.groupby(by='RecruitmentSource').agg({
    'Termd': 'count'
}).sort_values(by='Termd', ascending=False).reset_index()
datas_0
# Out:
#     RecruitmentSource  Termd
# 0              Indeed     66
# 1            LinkedIn     58
# 2   Employee Referral     26
# 3       Google Search     19
# 4  Diversity Job Fair     13
# 5       CareerBuilder     12
# 6             Website     12
# 7               Other      1

# %% [markdown]
# Disini kita diperlihatkan bahwasanya karyawan yang masih bekerja melalui jalur rekrutmennya.

# %%
dataset_1 = dataset[dataset['Termd'] == 1]
datas_1 = dataset_1.groupby(by='RecruitmentSource').agg({
    'Termd': 'count'
}).sort_values(by='Termd', ascending=False).reset_index()
datas_1
# Out:
#          RecruitmentSource  Termd
# 0            Google Search     30
# 1                   Indeed     21
# 2                 LinkedIn     18
# 3       Diversity Job Fair     16
# 4            CareerBuilder     11
# 5        Employee Referral      5
# 6  On-line Web application      1
# 7                    Other      1
# 8                  Website      1

# %% [markdown]
# disini kita dapat melihat jumlah karyawan yang sudah diberhentikan bekerja berdasarkan jalur rekrutmennya. setelah itu untuk mendapatkan jalur yang terbaik dalam merekrut karyawan dengan cara mencari rationya.

# %%
termination_rate = dataset.groupby('RecruitmentSource')['Termd'].mean()
sorted_termination_rate = termination_rate.sort_values(ascending=True)
sorted_termination_rate
# Out:
# RecruitmentSource
# Website                    0.076923
# Employee Referral          0.161290
# LinkedIn                   0.236842
# Indeed                     0.241379
# CareerBuilder              0.478261
# Other                      0.500000
# Diversity Job Fair         0.551724
# Google Search              0.612245
# On-line Web application    1.000000
# Name: Termd, dtype: float64

# %% [markdown]
# Dari pemaparan data diatas dapat kita lihat bahwasanya website memiliki ratio karyawan yang terkena terminate paling rendah, diikuti dengan Employee Referral, LinkedIn, serta Indeed. dan yang memiliki ratio karyawan yang terminate adalah jalur Online Web Application.

# %% [markdown]
# Lalu kita juga perlu mengecek skor performa dari karyawan berdasarkan jalur rekrutmennya.

# %%
perform_data0 = dataset[dataset['PerformanceScore'] == 'Exceeds']

perform_data0.groupby('RecruitmentSource').agg(
    total_recruit=('PerformanceScore', 'count')
).sort_values(by='total_recruit', ascending=False)
# Out:
#                     total_recruit
# RecruitmentSource
# Indeed                         12
# LinkedIn                        9
# Diversity Job Fair              6
# Employee Referral               5
# CareerBuilder                   2
# Google Search                   2
# Website                         1

# %% [markdown]
# Berdasarkan tabel diatas dapat dilihat bahawasanya jalur rekrutmen Indeed memiliki karyawan dengan performa exceed (yang memiliki skor performa diatas ekspetasi) terbanyak.

# %%
perform_data1 = dataset[dataset['PerformanceScore'] == 'Fully Meets']

perform_data1.groupby('RecruitmentSource').agg(
    total_recruit=('PerformanceScore', 'count')
).sort_values(by='total_recruit', ascending=False)
# Out:
#                          total_recruit
# RecruitmentSource
# Indeed                              66
# LinkedIn                            61
# Google Search                       43
# Employee Referral                   25
# Diversity Job Fair                  18
# CareerBuilder                       17
# Website                             10
# Other                                2
# On-line Web application              1

# %% [markdown]
# Berdasarkan tabel diatas dapat kita lihat bahwasanya jalur rekrutmen Indeed memiliki karyawan dengan skor performa yang memenuhi ekspetasi (Fully Meets) terbanyak.

# %%
perform_data2 = dataset[dataset['PerformanceScore'] == 'Needs Improvement']

perform_data2.groupby('RecruitmentSource').agg(
    total_recruit=('PerformanceScore', 'count')
).sort_values(by='total_recruit', ascending=False)
# Out:
#                     total_recruit
# RecruitmentSource
# CareerBuilder                   4
# Diversity Job Fair              4
# Indeed                          4
# Google Search                   3
# LinkedIn                        3

# %% [markdown]
# Berdasarkan tabel diatas dapat kita lihat bahwasanya jalur Career Builder, Diversity Job Fair, serta Indeed memiliki karyawan dengan skor performa yang membutuhkan peningkatan atau dibawah ekspetasi (Needs Improvement) dengan jumlah masihng masing 4 karyawan.

# %%
perform_data3 = dataset[dataset['PerformanceScore'] == 'PIP']

perform_data3.groupby('RecruitmentSource').agg(
    total_recruit=('PerformanceScore', 'count')
).sort_values(by='total_recruit', ascending=False)
# Out:
#                     total_recruit
# RecruitmentSource
# Indeed                          5
# LinkedIn                        3
# Website                         2
# Diversity Job Fair              1
# Employee Referral               1
# Google Search                   1

# %% [markdown]
# Berdasarkan tabel diatas dapat kita lihat bahwasanya jalur Indeed memiliki karyawan dengan skor performa yang membutuhkan perhatian kusus (PIP).

# %% [markdown]
# Berdasarkan pemaparan diatas melalui perbandingan jalur rekrutmennya dengan Total terminasi dan total PerformanceScore dapat ditarik kesimpulan bahwasanya Jalur rekrutmen yang memiliki rasio terminasi terkecil adalah jalur Indeed, LinkedIn, Google Search, Diversity Job Fair, serta Website.
